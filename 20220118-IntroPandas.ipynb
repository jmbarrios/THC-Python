# %%
import numpy as np
import pandas as pd

# %%
penguin_data = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv')

# %%
penguin_data
# Out:
#     species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0    Adelie  Torgersen            39.1  ...              181.0       3750.0    MALE
# 1    Adelie  Torgersen            39.5  ...              186.0       3800.0  FEMALE
# 2    Adelie  Torgersen            40.3  ...              195.0       3250.0  FEMALE
# 3    Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4    Adelie  Torgersen            36.7  ...              193.0       3450.0  FEMALE
# ..      ...        ...             ...  ...                ...          ...     ...
# 339  Gentoo     Biscoe             NaN  ...                NaN          NaN     NaN
# 340  Gentoo     Biscoe            46.8  ...              215.0       4850.0  FEMALE
# 341  Gentoo     Biscoe            50.4  ...              222.0       5750.0    MALE
# 342  Gentoo     Biscoe            45.2  ...              212.0       5200.0  FEMALE
# ...

# %%
type(penguin_data)
# Out:
# pandas.core.frame.DataFrame

# %%
penguin_data.head(10)
# Out:
#   species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1  ...              181.0       3750.0    MALE
# 1  Adelie  Torgersen            39.5  ...              186.0       3800.0  FEMALE
# 2  Adelie  Torgersen            40.3  ...              195.0       3250.0  FEMALE
# 3  Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7  ...              193.0       3450.0  FEMALE
# 5  Adelie  Torgersen            39.3  ...              190.0       3650.0    MALE
# 6  Adelie  Torgersen            38.9  ...              181.0       3625.0  FEMALE
# 7  Adelie  Torgersen            39.2  ...              195.0       4675.0    MALE
# 8  Adelie  Torgersen            34.1  ...              193.0       3475.0     NaN
# 9  Adelie  Torgersen            42.0  ...              190.0       4250.0     NaN
#
# [10 rows x 7 columns]

# %%
penguin_data.tail(10)
# Out:
#     species  island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 334  Gentoo  Biscoe            46.2  ...              217.0       4375.0  FEMALE
# 335  Gentoo  Biscoe            55.1  ...              230.0       5850.0    MALE
# 336  Gentoo  Biscoe            44.5  ...              217.0       4875.0     NaN
# 337  Gentoo  Biscoe            48.8  ...              222.0       6000.0    MALE
# 338  Gentoo  Biscoe            47.2  ...              214.0       4925.0  FEMALE
# 339  Gentoo  Biscoe             NaN  ...                NaN          NaN     NaN
# 340  Gentoo  Biscoe            46.8  ...              215.0       4850.0  FEMALE
# 341  Gentoo  Biscoe            50.4  ...              222.0       5750.0    MALE
# 342  Gentoo  Biscoe            45.2  ...              212.0       5200.0  FEMALE
# 343  Gentoo  Biscoe            49.9  ...              213.0       5400.0    MALE
#
# [10 rows x 7 columns]

# %%
penguin_data.shape
# Out:
# (344, 7)

# %%
penguin_data['species']
# Out:
# 0      Adelie
# 1      Adelie
# 2      Adelie
# 3      Adelie
# 4      Adelie
#         ...
# 339    Gentoo
# 340    Gentoo
# 341    Gentoo
# 342    Gentoo
# 343    Gentoo
# Name: species, Length: 344, dtype: object

# %%
penguin_data['bill_depth_mm'] * penguin_data['bill_length_mm']
# Out:
# 0      731.17
# 1      687.30
# 2      725.40
# 3         NaN
# 4      708.31
#         ...
# 339       NaN
# 340    669.24
# 341    791.28
# 342    668.96
# 343    803.39
# Length: 344, dtype: float64

# %%
species = penguin_data['species']

# %%
type(species)
# Out:
# pandas.core.series.Series

# %%
penguin_data.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
penguin_data.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# ## Más métodos de acceso a los datos

# %%
penguin_data.loc[10:20, ['species', 'sex']]
# Out:
#    species     sex
# 10  Adelie     NaN
# 11  Adelie     NaN
# 12  Adelie  FEMALE
# 13  Adelie    MALE
# 14  Adelie    MALE
# 15  Adelie  FEMALE
# 16  Adelie  FEMALE
# 17  Adelie    MALE
# 18  Adelie  FEMALE
# 19  Adelie    MALE
# 20  Adelie  FEMALE

# %%
penguin_data.iloc[10:20, [0, 6]]
# Out:
#    species     sex
# 10  Adelie     NaN
# 11  Adelie     NaN
# 12  Adelie  FEMALE
# 13  Adelie    MALE
# 14  Adelie    MALE
# 15  Adelie  FEMALE
# 16  Adelie  FEMALE
# 17  Adelie    MALE
# 18  Adelie  FEMALE
# 19  Adelie    MALE

# %%
gentoo_data = penguin_data[
    penguin_data['species'] == 'Gentoo'             
]

# %%
type(gentoo_data)
# Out:
# pandas.core.frame.DataFrame

# %%
gentoo_data.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      123.000000     123.000000         123.000000   123.000000
# mean        47.504878      14.982114         217.186992  5076.016260
# std          3.081857       0.981220           6.484976   504.116237
# min         40.900000      13.100000         203.000000  3950.000000
# 25%         45.300000      14.200000         212.000000  4700.000000
# 50%         47.300000      15.000000         216.000000  5000.000000
# 75%         49.550000      15.700000         221.000000  5500.000000
# max         59.600000      17.300000         231.000000  6300.000000

# %%
gentoo_data[ gentoo_data['sex'] == 'FEMALE' ].describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count       58.000000      58.000000          58.000000    58.000000
# mean        45.563793      14.237931         212.706897  4679.741379
# std          2.051247       0.540249           3.897856   281.578294
# min         40.900000      13.100000         203.000000  3950.000000
# 25%         43.850000      13.800000         210.000000  4462.500000
# 50%         45.500000      14.250000         212.000000  4700.000000
# 75%         46.875000      14.600000         215.000000  4875.000000
# max         50.500000      15.500000         222.000000  5200.000000

# %%
gentoo_data[gentoo_data['sex'] == 'MALE'].describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count       61.000000      61.000000          61.000000    61.000000
# mean        49.473770      15.718033         221.540984  5484.836066
# std          2.720594       0.741060           5.673252   313.158596
# min         44.400000      14.100000         208.000000  4750.000000
# 25%         48.100000      15.200000         218.000000  5300.000000
# 50%         49.500000      15.700000         221.000000  5500.000000
# 75%         50.500000      16.100000         225.000000  5700.000000
# max         59.600000      17.300000         231.000000  6300.000000

# %%
penguin_data[ (penguin_data['species'] == 'Gentoo') | (penguin_data['species'] == 'Chinstrap') ]
# Out:
#        species  island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 152  Chinstrap   Dream            46.5  ...              192.0       3500.0  FEMALE
# 153  Chinstrap   Dream            50.0  ...              196.0       3900.0    MALE
# 154  Chinstrap   Dream            51.3  ...              193.0       3650.0    MALE
# 155  Chinstrap   Dream            45.4  ...              188.0       3525.0  FEMALE
# 156  Chinstrap   Dream            52.7  ...              197.0       3725.0    MALE
# ..         ...     ...             ...  ...                ...          ...     ...
# 339     Gentoo  Biscoe             NaN  ...                NaN          NaN     NaN
# 340     Gentoo  Biscoe            46.8  ...              215.0       4850.0  FEMALE
# 341     Gentoo  Biscoe            50.4  ...              222.0       5750.0    MALE
# 342     Gentoo  Biscoe            45.2  ...              212.0       5200.0  FEMALE
# ...

# %%
penguin_data[ penguin_data['species'].isin(['Gentoo', 'Chinstrap']) ]
# Out:
#        species  island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 152  Chinstrap   Dream            46.5  ...              192.0       3500.0  FEMALE
# 153  Chinstrap   Dream            50.0  ...              196.0       3900.0    MALE
# 154  Chinstrap   Dream            51.3  ...              193.0       3650.0    MALE
# 155  Chinstrap   Dream            45.4  ...              188.0       3525.0  FEMALE
# 156  Chinstrap   Dream            52.7  ...              197.0       3725.0    MALE
# ..         ...     ...             ...  ...                ...          ...     ...
# 339     Gentoo  Biscoe             NaN  ...                NaN          NaN     NaN
# 340     Gentoo  Biscoe            46.8  ...              215.0       4850.0  FEMALE
# 341     Gentoo  Biscoe            50.4  ...              222.0       5750.0    MALE
# 342     Gentoo  Biscoe            45.2  ...              212.0       5200.0  FEMALE
# ...

# %%
species_focus = ['Gentoo', 'Chinstrap']
penguin_data[ penguin_data['species'].isin(species_focus) ]
# Out:
#        species  island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 152  Chinstrap   Dream            46.5  ...              192.0       3500.0  FEMALE
# 153  Chinstrap   Dream            50.0  ...              196.0       3900.0    MALE
# 154  Chinstrap   Dream            51.3  ...              193.0       3650.0    MALE
# 155  Chinstrap   Dream            45.4  ...              188.0       3525.0  FEMALE
# 156  Chinstrap   Dream            52.7  ...              197.0       3725.0    MALE
# ..         ...     ...             ...  ...                ...          ...     ...
# 339     Gentoo  Biscoe             NaN  ...                NaN          NaN     NaN
# 340     Gentoo  Biscoe            46.8  ...              215.0       4850.0  FEMALE
# 341     Gentoo  Biscoe            50.4  ...              222.0       5750.0    MALE
# 342     Gentoo  Biscoe            45.2  ...              212.0       5200.0  FEMALE
# ...

# %%
penguin_data['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
penguin_data['sex'].unique()
# Out:
# array(['MALE', 'FEMALE', nan], dtype=object)

# %%
penguin_data['island'].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
penguin_data['species']
# Out:
# 0      Adelie
# 1      Adelie
# 2      Adelie
# 3      Adelie
# 4      Adelie
#         ...
# 339    Gentoo
# 340    Gentoo
# 341    Gentoo
# 342    Gentoo
# 343    Gentoo
# Name: species, Length: 344, dtype: object

# %%
penguin_data['species'] = penguin_data['species'].astype('category')

# %%
penguin_data['species']
# Out:
# 0      Adelie
# 1      Adelie
# 2      Adelie
# 3      Adelie
# 4      Adelie
#         ...
# 339    Gentoo
# 340    Gentoo
# 341    Gentoo
# 342    Gentoo
# 343    Gentoo
# Name: species, Length: 344, dtype: category
# Categories (3, object): ['Adelie', 'Chinstrap', 'Gentoo']

# %%
penguin_data['island'] = penguin_data['island'].astype('category')
penguin_data['sex'] = penguin_data['sex'].astype('category')

# %%
penguin_data.dtypes
# Out:
# species              category
# island               category
# bill_length_mm        float64
# bill_depth_mm         float64
# flipper_length_mm     float64
# body_mass_g           float64
# sex                  category
# dtype: object

# %%
penguin_data['body_mass_kg'] = penguin_data['body_mass_g']/1000

# %%
penguin_data
# Out:
#     species     island  bill_length_mm  ...  body_mass_g     sex  body_mass_kg
# 0    Adelie  Torgersen            39.1  ...       3750.0    MALE          3.75
# 1    Adelie  Torgersen            39.5  ...       3800.0  FEMALE          3.80
# 2    Adelie  Torgersen            40.3  ...       3250.0  FEMALE          3.25
# 3    Adelie  Torgersen             NaN  ...          NaN     NaN           NaN
# 4    Adelie  Torgersen            36.7  ...       3450.0  FEMALE          3.45
# ..      ...        ...             ...  ...          ...     ...           ...
# 339  Gentoo     Biscoe             NaN  ...          NaN     NaN           NaN
# 340  Gentoo     Biscoe            46.8  ...       4850.0  FEMALE          4.85
# 341  Gentoo     Biscoe            50.4  ...       5750.0    MALE          5.75
# 342  Gentoo     Biscoe            45.2  ...       5200.0  FEMALE          5.20
# 343  Gentoo     Biscoe            49.9  ...       5400.0    MALE          5.40
#
# [344 rows x 8 columns]

# %%
penguin_data.value_counts('sex')
# Out:
# sex
# MALE      168
# FEMALE    165
# dtype: int64

# %%
penguin_data.value_counts('species')
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# dtype: int64

# %%
penguin_data.value_counts(['species', 'sex'])
# Out:
# species    sex
# Adelie     MALE      73
#            FEMALE    73
# Gentoo     MALE      61
#            FEMALE    58
# Chinstrap  MALE      34
#            FEMALE    34
# dtype: int64

# %%
penguin_data.value_counts(['island', 'species', 'sex'])
# Out:
# island     species    sex
# Biscoe     Gentoo     MALE      61
#                       FEMALE    58
# Dream      Chinstrap  MALE      34
#                       FEMALE    34
#            Adelie     MALE      28
#                       FEMALE    27
# Torgersen  Adelie     FEMALE    24
#                       MALE      23
# Biscoe     Adelie     MALE      22
#                       FEMALE    22
# dtype: int64

# %%
# ?penguin_data.plot

# %%
import matplotlib.pyplot as plt

# %%
penguin_data.plot('bill_length_mm', 'bill_depth_mm', kind='scatter')

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
penguin_data['color'] = penguin_data['species']

# %%
penguin_data.dtypes
# Out:
# species              category
# island               category
# bill_length_mm        float64
# bill_depth_mm         float64
# flipper_length_mm     float64
# body_mass_g           float64
# sex                  category
# body_mass_kg          float64
# color                category
# dtype: object

# %%
penguin_data['color'].cat.categories = ['red', 'blue', 'green']

# %%
penguin_data[['species', 'color']]
# Out:
#     species  color
# 0    Adelie    red
# 1    Adelie    red
# 2    Adelie    red
# 3    Adelie    red
# 4    Adelie    red
# ..      ...    ...
# 339  Gentoo  green
# 340  Gentoo  green
# 341  Gentoo  green
# 342  Gentoo  green
# 343  Gentoo  green
#
# [344 rows x 2 columns]

# %%
penguin_data.plot('bill_length_mm', 'bill_depth_mm', c='color', kind='scatter')

# %%
penguin_data.groupby(by='species').describe()
# Out:
#           bill_length_mm                             ... body_mass_kg
#                    count       mean       std   min  ...          25%  50%   75%    max
# species                                              ...
# Adelie             151.0  38.791391  2.663405  32.1  ...       3.3500  3.7  4.00  4.775
# Chinstrap           68.0  48.833824  3.339256  40.9  ...       3.4875  3.7  3.95  4.800
# Gentoo             123.0  47.504878  3.081857  40.9  ...       4.7000  5.0  5.50  6.300
#
# [3 rows x 40 columns]

# %%
penguin_data.groupby(by='species').size()
# Out:
# species
# Adelie       152
# Chinstrap     68
# Gentoo       124
# dtype: int64

# %%
penguin_data.groupby(by='species').mean()
# Out:
#            bill_length_mm  bill_depth_mm  ...  body_mass_g  body_mass_kg
# species                                   ...
# Adelie          38.791391      18.346358  ...  3700.662252      3.700662
# Chinstrap       48.833824      18.420588  ...  3733.088235      3.733088
# Gentoo          47.504878      14.982114  ...  5076.016260      5.076016
#
# [3 rows x 5 columns]

# %%
penguin_data.groupby(by='species').size().sort_values(ascending=False).plot(kind='bar')
